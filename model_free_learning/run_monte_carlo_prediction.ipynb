# %%
from models import monte_carlo_method
import gym

# %%
# instantiate env and monte-carlo prediction:

env = gym.make('Blackjack-v1')

mc = monte_carlo_method.MonteCarloPrediction(env=env, 
                                             num_timesteps=1000,
                                             num_iterations=100000)

# %%
# run monte carlo prediction:

df = mc.value_function()

# %%
# Look at average return (value) for each state:

df.sort_values('value',ascending=False)
# Out:
#                state  total_return     N     value
# 129    (21, 7, True)         419.0   423  0.990544
# 130    (21, 4, True)         462.0   467  0.989293
# 197    (21, 9, True)         441.0   447  0.986577
# 35     (21, 8, True)         433.0   439  0.986333
# 174    (21, 5, True)         437.0   444  0.984234
# ..               ...           ...   ...       ...
# 7    (15, 10, False)       -2188.0  3857 -0.567280
# 137   (15, 1, False)        -588.0   957 -0.614420
# 5     (17, 1, False)        -602.0   942 -0.639066
# 148   (16, 1, False)        -657.0   960 -0.684375
# 259    (17, 1, True)        -104.0   146 -0.712329
#
# [280 rows x 4 columns]
